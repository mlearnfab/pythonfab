# %% [markdown]
# # Python for Absolute Beginners

# %% [markdown]
# ## Practice Worksheet for Unit 1

# %% [markdown]
# ### a) Program as a series of instructions

# %% [markdown]
# ### b) Basic string operations

# %% [markdown]
# ### c) Print statement and formatting

# %% [markdown]
# ### d) Input statement
